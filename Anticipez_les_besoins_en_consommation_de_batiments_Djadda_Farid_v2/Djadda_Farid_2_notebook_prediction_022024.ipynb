# %%
# !pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in c:\users\farid\anaconda3\lib\site-packages (2.6.3)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\farid\anaconda3\lib\site-packages (from category_encoders) (0.5.2)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\farid\anaconda3\lib\site-packages (from category_encoders) (0.13.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\farid\anaconda3\lib\site-packages (from category_encoders) (1.0.2)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\farid\anaconda3\lib\site-packages (from category_encoders) (1.21.5)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\farid\anaconda3\lib\site-packages (from category_encoders) (1.4.4)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\farid\anaconda3\lib\site-packages (from category_encoders) (1.9.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\farid\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\farid\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: six in c:\users\farid\anaconda3\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\farid\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\farid\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.1.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\farid\anaconda3\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\farid\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels>=0.9.0->category_encoders) (3.0.9)

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

from sklearn import decomposition
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, RobustScaler, PolynomialFeatures, MinMaxScaler, OneHotEncoder, OrdinalEncoder, LabelBinarizer
from category_encoders import TargetEncoder

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import learning_curve

from sklearn.compose import ColumnTransformer

from mpl_toolkits.mplot3d import Axes3D

# Modèles linéaires
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet

# Modèles ensembliste
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

# Modèle de Support Vector
from sklearn.svm import SVR

# Modèle de régression KNN
from sklearn import neighbors
from sklearn.neighbors import KNeighborsRegressor

# Modèle dummy
from sklearn.dummy import DummyRegressor

# Métriques 
from sklearn.metrics import *


# Pipeline 
from sklearn.pipeline import make_pipeline, Pipeline

from timeit import default_timer as timer

import sys
import os
import warnings
warnings.filterwarnings("ignore")

#%run my_function.ipynb

import warnings
warnings.filterwarnings('ignore')

# %%
path = 'C:/Users/Farid/Documents/OC/Cursus_Data_Scientist/Projet_4/data'

# %%
os.listdir(path)
# Out:
# ['2016_Building_Energy_Benchmarking.csv', 'energy_cleaned.csv']

# %%
energy_benchmarking = pd.read_csv(path + '/energy_cleaned.csv')
energy_benchmarking_ml = energy_benchmarking.copy()

# %%
energy_benchmarking_ml.head()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  ZipCode  \
# 0              1      2016  NonResidential               Hotel  98101.0
# 1              2      2016  NonResidential               Hotel  98101.0
# 2              3      2016  NonResidential               Hotel  98101.0
# 3              5      2016  NonResidential               Hotel  98101.0
# 4              8      2016  NonResidential               Hotel  98121.0
#
#   TaxParcelIdentificationNumber  CouncilDistrictCode Neighborhood  \
# 0                    0659000030                    7     DOWNTOWN
# 1                    0659000220                    7     DOWNTOWN
# 2                    0659000475                    7     DOWNTOWN
# 3                    0659000640                    7     DOWNTOWN
# 4                    0659000970                    7     DOWNTOWN
#
#    NumberofBuildings  NumberofFloors  ...  Electricity(kBtu) NaturalGas(kBtu)  \
# 0                1.0              12  ...          3946027.0        1276453.0
# 1                1.0              11  ...          3242851.0        5145082.0
# 2                1.0              41  ...         49526664.0        1493800.0
# 3                1.0              10  ...          2768924.0        1811213.0
# 4                1.0              18  ...          5368607.0        8803998.0
#
#   ComplianceStatus  TotalGHGEmissions  GHGEmissionsIntensity  Ancienneté  \
# 0        Compliant             249.98                   2.83          89
# 1        Compliant             295.86                   2.86          20
# 2        Compliant            2089.28                   2.19          47
# 3        Compliant             286.43                   4.67          90
# 4        Compliant             505.01                   2.88          36
#
#    BuildingAreaPercentage  ParkingAreaPercentage  AverageGFAperBuilding  \
# 0                 1.00000                0.00000                88434.0
# 1                 0.85455                0.14545               103566.0
# 2                 0.79425                0.20575               956110.0
# 3                 1.00000                0.00000                61320.0
# 4                 0.64688                0.35312               175580.0
#
#    AverageGFAperFloor
# 0             7369.50
# 1             9415.09
# 2            23319.76
# 3             6132.00
# 4             9754.44
#
# [5 rows x 29 columns]

# %%
energy_benchmarking_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1618 entries, 0 to 1617
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   OSEBuildingID                  1618 non-null   int64
#  1   DataYear                       1618 non-null   int64
#  2   BuildingType                   1618 non-null   object
#  3   PrimaryPropertyType            1618 non-null   object
#  4   ZipCode                        1602 non-null   float64
#  5   TaxParcelIdentificationNumber  1618 non-null   object
#  6   CouncilDistrictCode            1618 non-null   int64
#  7   Neighborhood                   1618 non-null   object
#  8   NumberofBuildings              1618 non-null   float64
#  9   NumberofFloors                 1618 non-null   int64
#  10  PropertyGFATotal               1618 non-null   int64
#  11  ListOfAllPropertyUseTypes      1618 non-null   object
#  12  LargestPropertyUseType         1618 non-null   object
#  13  ENERGYSTARScore                1073 non-null   float64
#  14  SiteEUIWN(kBtu/sf)             1618 non-null   float64
#  15  SourceEUIWN(kBtu/sf)           1618 non-null   float64
#  16  SiteEnergyUseWN(kBtu)          1618 non-null   float64
#  17  SteamUse(kBtu)                 1618 non-null   float64
#  18  Electricity(kWh)               1618 non-null   float64
#  19  Electricity(kBtu)              1618 non-null   float64
#  20  NaturalGas(kBtu)               1618 non-null   float64
#  21  ComplianceStatus               1618 non-null   object
#  22  TotalGHGEmissions              1618 non-null   float64
#  23  GHGEmissionsIntensity          1618 non-null   float64
#  24  Ancienneté                     1618 non-null   int64
#  25  BuildingAreaPercentage         1618 non-null   float64
#  26  ParkingAreaPercentage          1618 non-null   float64
#  27  AverageGFAperBuilding          1618 non-null   float64
#  28  AverageGFAperFloor             1618 non-null   float64
# dtypes: float64(16), int64(6), object(7)
# memory usage: 366.7+ KB

# %% [markdown]
# # Fonction

# %%
# fonction titre 
def print_titre(titre):
    longueur_ligne = len(titre) + 10
    ligne = "-" * longueur_ligne

    print(ligne)
    print(f"| {titre} |")
    print(ligne)
    return

# %%
def select_features_and_targets(df, col):
    selected_columns = numeric_features + categorical_features + [col]
    df_selected = df[selected_columns]

    return df_selected

# %%
def train_model(pipeline, grid, X_train, y_train):
    cv_model = GridSearchCV(pipeline, grid, cv=5, n_jobs=-1, return_train_score=True, verbose=2)
    cv_model.fit(X_train, y_train)
    
    return cv_model

# %%
def display_evaluate_model(cv_model, X_test, y_test, model_name, config_name, df_cv_results):
    """
    Affiche et évalue les résultats d'un modèle avec une configuration spécifique.

    Parameters:
    - cv_model: Modèle après la recherche sur grille (GridSearchCV).
    - X_test (DataFrame): Features de test.
    - y_test (Series): Labels de test.
    - model_name (str): Nom du modèle.
    - config_name (str): Nom de la configuration.
    - df_cv_results (DataFrame): Résultats de la recherche sur grille.

    Returns:
    - dict: Informations sur les résultats du modèle.
    """
    # Info sur les résultats du modèle
    result_info = {
        "model_name": model_name,
        "config_name": config_name,
        "Test score": cv_model.best_score_,
        "Params": cv_model.best_params_,
        "df_cv_results": df_cv_results
    }
    
    print_titre(f"Meilleur Model - {model_name}")
    print(f'{model_name} - {config_name}:\n Test score: {cv_model.best_score_}\n Params: {cv_model.best_params_}\n')
    
    print_titre("Details Models")
    print(df_cv_results.head(3))
    
    # Courbe d'apprentissage
    # print_titre("Courbe d'apprentissage")
    # plt.figure(figsize=(4, 3))
    # N, train_score, val_score = learning_curve(cv_model.best_estimator_, X_train, y_train, train_sizes=np.linspace(0.2, 1.0, 5), cv=5)
    # plt.plot(N, train_score.mean(axis=1), label='Entraînement')
    # plt.plot(N, val_score.mean(axis=1), label='Validation')
    # plt.xlabel('Taille de l\'ensemble d\'entraînement')
    # plt.ylabel('Score moyen')
    # plt.legend()
    # plt.show()

    # Scores Moyens d'Entraînement et de Validation
    print_titre("Scores Moyens d'Entraînement et de Validation")
    plt.figure(figsize=(4, 3))
    plt.plot(cv_model.cv_results_["mean_train_score"], label='Entraînement')
    plt.plot(cv_model.cv_results_["mean_test_score"], label='Validation')
    plt.xlabel('Nombre d\'itérations')
    plt.ylabel('Score (R^2)')
    plt.show()

    return result_info

# %%
def calculate_best_model_performance(cv_model, X_test, y_test, model_name, fit_time):
    """
    Calcule les performances du meilleur modèle sélectionné.

    Parameters:
    - cv_model: Modèle entraîné avec GridSearchCV.
    - X_test (DataFrame): Features de test.
    - y_test (Series): Labels de test.
    - model_name (str): Nom du modèle.
    - fit_time (float): Temps de calcul du modèle.

    Returns:
    - dict: Informations sur les performances du meilleur modèle sélectionné.
    """
    best_model_performance = {
        'model': model_name,
        'best_params': str(cv_model.best_params_),
        'Test_score': cv_model.best_score_.round(3),
        'fit_time': fit_time
    }

    return best_model_performance

# %%
def run_models_with_preprocessors(models, preprocessor_configs, grid_configs, X_train, y_train, X_test, y_test, numeric_features, categorical_features):
    """
    Entraîne plusieurs modèles avec différentes configurations de prétraitement et affiche les résultats.

    Parameters:
    - models (dict): Dictionnaire de modèles à entraîner.
    - preprocessor_configs (list): Liste de tuples contenant le nom de la configuration, le préprocesseur numérique et le préprocesseur catégorique.
    - grid_configs (dict): Dictionnaire contenant les grilles de recherche spécifiques à chaque modèle.
    - X_train (DataFrame): Features d'entraînement.
    - y_train (Series): Labels d'entraînement.
    - X_test (DataFrame): Features de test.
    - y_test (Series): Labels de test.
    - numeric_features (list): Liste des colonnes numériques.
    - categorical_features (list): Liste des colonnes catégoriques.

    Returns:
    - dict: Résultats de l'évaluation pour chaque modèle et configuration.
    - DataFrame: Récapitulatif des performances des meilleurs modèles sélectionnés.
    """
    results = {}
    best_models_summary = []

    for model_name, model in models.items():
        for config_name, num_preprocessor, cat_preprocessor in preprocessor_configs:
            # Création du préprocesseur
            preprocessor = ColumnTransformer(
                transformers=[
                    ("num", num_preprocessor, numeric_features),
                    ("cat", cat_preprocessor, categorical_features),
                ]
            )

            # Création de la pipeline
            pipeline = Pipeline(
                steps=[("preprocessor", preprocessor), ("regressor", model)]
            )

            # Création de la grille de recherche spécifique au modèle
            grid = grid_configs.get(model_name, {})  # Utiliser une grille vide si le modèle n'est pas trouvé dans grid_configs

            # Entraînement du modèle
            start_time = timer()
            cv_model = train_model(pipeline, grid, X_train, y_train)
            end_time = timer()

            # Affichage des résultats
            df_cv_results = pd.DataFrame(cv_model.cv_results_).sort_values(by="rank_test_score", ascending=True)[['params', "mean_train_score", "mean_test_score"]]
            result_info = display_evaluate_model(cv_model, X_test, y_test, model_name, config_name, df_cv_results)
            results[f"{model_name} - {config_name}"] = result_info

            # Calcul des performances du meilleur modèle sélectionné
            best_model_summary = calculate_best_model_performance(cv_model, X_test, y_test, model_name, end_time - start_time)
            best_models_summary.append(best_model_summary)

    # Création d'un DataFrame récapitulatif des performances des meilleurs modèles sélectionnés
    best_models_summary_df = pd.DataFrame(best_models_summary)

    return results, best_models_summary_df

# %% [markdown]
# # Analyse Comparative des Modèles Utilisés

# %%
energy_benchmarking_ml.columns
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'ZipCode', 'TaxParcelIdentificationNumber', 'CouncilDistrictCode',
#        'Neighborhood', 'NumberofBuildings', 'NumberofFloors',
#        'PropertyGFATotal', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'ENERGYSTARScore', 'SiteEUIWN(kBtu/sf)',
#        'SourceEUIWN(kBtu/sf)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(kBtu)',
#        'ComplianceStatus', 'TotalGHGEmissions', 'GHGEmissionsIntensity',
#        'Ancienneté', 'BuildingAreaPercentage', 'ParkingAreaPercentage',
#        'AverageGFAperBuilding', 'AverageGFAperFloor'],
#       dtype='object')

# %%
numeric_features = ['Ancienneté', 'BuildingAreaPercentage', 'ParkingAreaPercentage',
                     'NumberofBuildings', 'NumberofFloors', 'PropertyGFATotal', 'ENERGYSTARScore']

categorical_features = ['Neighborhood', 'PrimaryPropertyType', 'BuildingType', 'LargestPropertyUseType']

# %%
energy_benchmarking_ml = energy_benchmarking_ml[numeric_features + categorical_features + ['SiteEnergyUseWN(kBtu)']]

# %%
energy_benchmarking_ml.columns
# Out:
# Index(['Ancienneté', 'BuildingAreaPercentage', 'ParkingAreaPercentage',
#        'NumberofBuildings', 'NumberofFloors', 'PropertyGFATotal',
#        'ENERGYSTARScore', 'Neighborhood', 'PrimaryPropertyType',
#        'BuildingType', 'LargestPropertyUseType', 'SiteEnergyUseWN(kBtu)'],
#       dtype='object')

# %%
# Diviser les données
X = energy_benchmarking_ml.dropna().drop(columns=['SiteEnergyUseWN(kBtu)'])
y = energy_benchmarking_ml.dropna()['SiteEnergyUseWN(kBtu)']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=60)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1073 entries, 0 to 1613
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Ancienneté              1073 non-null   int64
#  1   BuildingAreaPercentage  1073 non-null   float64
#  2   ParkingAreaPercentage   1073 non-null   float64
#  3   NumberofBuildings       1073 non-null   float64
#  4   NumberofFloors          1073 non-null   int64
#  5   PropertyGFATotal        1073 non-null   int64
#  6   ENERGYSTARScore         1073 non-null   float64
#  7   Neighborhood            1073 non-null   object
#  8   PrimaryPropertyType     1073 non-null   object
#  9   BuildingType            1073 non-null   object
#  10  LargestPropertyUseType  1073 non-null   object
# dtypes: float64(4), int64(3), object(4)
# memory usage: 100.6+ KB

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 1073 entries, 0 to 1613
# Series name: SiteEnergyUseWN(kBtu)
# Non-Null Count  Dtype
# --------------  -----
# 1073 non-null   float64
# dtypes: float64(1)
# memory usage: 16.8 KB

# %%
# Liste des modèles à tester
models = {
    # "KNN": KNeighborsRegressor(),
    "ElasticNet": ElasticNet(),
    "GradientBoosting": GradientBoostingRegressor(),
    # "SVR": SVR(),
    "RandomForest": RandomForestRegressor()
}

# Grilles de recherche pour chaque modèle
grid_configs = {
    # "KNN": {"regressor__n_neighbors": range(2, 15)},
    "ElasticNet": {"regressor__alpha": np.logspace(0.00001, 10, 30), "regressor__l1_ratio": [0.1, 0.3, 0.5, 0.7, 0.9]},
    "GradientBoosting": {"regressor__n_estimators": np.linspace(10, 400, 30, dtype=int), "regressor__learning_rate": [1, 0.5, 0.25, 0.1, 0.05, 0.01]},
    # "SVR": {"regressor__C": np.logspace(-2, 3, 6)},
    "RandomForest": {"regressor__n_estimators": np.linspace(10, 200, 20,dtype=int), "regressor__min_samples_leaf": [1, 4]}
}

# Liste des préprocesseurs pour tester différentes combinaisons
preprocessor_configs = [
    ("RobustScaler + OneHotEncoder", RobustScaler(), OneHotEncoder(handle_unknown='ignore')),
    ("StandardScaler + OneHotEncoder", StandardScaler(), OneHotEncoder(handle_unknown='ignore')),
    ("MinMaxScaler + OneHotEncoder", MinMaxScaler(), OneHotEncoder(handle_unknown='ignore')),
    ("PolynomialFeatures + OneHotEncoder", PolynomialFeatures(), OneHotEncoder(handle_unknown='ignore')),
    ("RobustScaler + TargetEncoder", RobustScaler(), TargetEncoder(cols=categorical_features)),
    ("StandardScaler + TargetEncoder", StandardScaler(), TargetEncoder(cols=categorical_features)),
    ("MinMaxScaler + TargetEncoder", MinMaxScaler(), TargetEncoder(cols=categorical_features)),
    ("PolynomialFeatures + TargetEncoder", PolynomialFeatures(), TargetEncoder(cols=categorical_features)),
]

# %%
models_wth_energy_star, best_models_summary_e = run_models_with_preprocessors(models, preprocessor_configs, grid_configs, X_train, y_train, X_test, y_test, numeric_features, categorical_features)
# Out:
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# -------------------------------------
# | Meilleur Model - ElasticNet |
# -------------------------------------
# ElasticNet - RobustScaler + OneHotEncoder:
#  Test score: 0.475581747696049
#  Params: {'regressor__alpha': 1.0000230261160268, 'regressor__l1_ratio': 0.9}
#
# ------------------------
# | Details Models |
# ------------------------
#                                               params  mean_train_score  \
# 4  {'regressor__alpha': 1.0000230261160268, 'regr...          0.529352
# 9  {'regressor__alpha': 2.2122654732913327, 'regr...          0.494254
# 3  {'regressor__alpha': 1.0000230261160268, 'regr...          0.478716
#
#    mean_test_score
# 4         0.475582
# 9         0.464047
# 3         0.457397
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# -------------------------------------
# | Meilleur Model - ElasticNet |
# -------------------------------------
# ElasticNet - StandardScaler + OneHotEncoder:
#  Test score: 0.5067774621131468
#  Params: {'regressor__alpha': 1.0000230261160268, 'regressor__l1_ratio': 0.9}
#
# ------------------------
# | Details Models |
# ------------------------
#                                               params  mean_train_score  \
# 4  {'regressor__alpha': 1.0000230261160268, 'regr...          0.532655
# 9  {'regressor__alpha': 2.2122654732913327, 'regr...          0.502429
# 3  {'regressor__alpha': 1.0000230261160268, 'regr...          0.488702
#
#    mean_test_score
# 4         0.506777
# 9         0.506428
# 3         0.501265
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# -------------------------------------
# | Meilleur Model - ElasticNet |
# -------------------------------------
# ElasticNet - MinMaxScaler + OneHotEncoder:
#  Test score: 0.2104444224410969
#  Params: {'regressor__alpha': 1.0000230261160268, 'regressor__l1_ratio': 0.9}
#
# ------------------------
# | Details Models |
# ------------------------
#                                               params  mean_train_score  \
# 4  {'regressor__alpha': 1.0000230261160268, 'regr...          0.254048
# 9  {'regressor__alpha': 2.2122654732913327, 'regr...          0.155492
# 3  {'regressor__alpha': 1.0000230261160268, 'regr...          0.125898
#
#    mean_test_score
# 4         0.210444
# 9         0.137312
# 3         0.112865
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# -------------------------------------
# | Meilleur Model - ElasticNet |
# -------------------------------------
# ElasticNet - PolynomialFeatures + OneHotEncoder:
#  Test score: 0.5784302673567744
#  Params: {'regressor__alpha': 4520357245.49924, 'regressor__l1_ratio': 0.5}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                 params  mean_train_score  \
# 142  {'regressor__alpha': 4520357245.49924, 'regres...          0.592275
# 141  {'regressor__alpha': 4520357245.49924, 'regres...          0.587130
# 148  {'regressor__alpha': 10000000000.0, 'regressor...          0.587411
#
#      mean_test_score
# 142         0.578430
# 141         0.578155
# 148         0.577832
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# -------------------------------------
# | Meilleur Model - ElasticNet |
# -------------------------------------
# ElasticNet - RobustScaler + TargetEncoder:
#  Test score: 0.35475658313649283
#  Params: {'regressor__alpha': 1.0000230261160268, 'regressor__l1_ratio': 0.9}
#
# ------------------------
# | Details Models |
# ------------------------
#                                               params  mean_train_score  \
# 4  {'regressor__alpha': 1.0000230261160268, 'regr...          0.563117
# 9  {'regressor__alpha': 2.2122654732913327, 'regr...          0.551534
# 3  {'regressor__alpha': 1.0000230261160268, 'regr...          0.545129
#
#    mean_test_score
# 4         0.354757
# 9         0.332410
# 3         0.321184
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# -------------------------------------
# | Meilleur Model - ElasticNet |
# -------------------------------------
# ElasticNet - StandardScaler + TargetEncoder:
#  Test score: 0.37971959648331677
#  Params: {'regressor__alpha': 1.0000230261160268, 'regressor__l1_ratio': 0.9}
#
# ------------------------
# | Details Models |
# ------------------------
#                                               params  mean_train_score  \
# 4  {'regressor__alpha': 1.0000230261160268, 'regr...          0.569586
# 9  {'regressor__alpha': 2.2122654732913327, 'regr...          0.559512
# 3  {'regressor__alpha': 1.0000230261160268, 'regr...          0.552613
#
#    mean_test_score
# 4         0.379720
# 9         0.363583
# 3         0.349725
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# -------------------------------------
# | Meilleur Model - ElasticNet |
# -------------------------------------
# ElasticNet - MinMaxScaler + TargetEncoder:
#  Test score: 0.0037003359919073773
#  Params: {'regressor__alpha': 1.0000230261160268, 'regressor__l1_ratio': 0.9}
#
# ------------------------
# | Details Models |
# ------------------------
#                                               params  mean_train_score  \
# 4  {'regressor__alpha': 1.0000230261160268, 'regr...          0.378169
# 9  {'regressor__alpha': 2.2122654732913327, 'regr...          0.356768
# 3  {'regressor__alpha': 1.0000230261160268, 'regr...          0.351272
#
#    mean_test_score
# 4         0.003700
# 9        -0.033786
# 3        -0.043358
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# -------------------------------------
# | Meilleur Model - ElasticNet |
# -------------------------------------
# ElasticNet - PolynomialFeatures + TargetEncoder:
#  Test score: 0.46273993428906585
#  Params: {'regressor__alpha': 4520357245.49924, 'regressor__l1_ratio': 0.9}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                 params  mean_train_score  \
# 144  {'regressor__alpha': 4520357245.49924, 'regres...          0.655613
# 138  {'regressor__alpha': 2043362962.6937475, 'regr...          0.655264
# 131  {'regressor__alpha': 923673057.3597437, 'regre...          0.655234
#
#      mean_test_score
# 144         0.462740
# 138         0.462677
# 131         0.462594
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# -------------------------------------------
# | Meilleur Model - GradientBoosting |
# -------------------------------------------
# GradientBoosting - RobustScaler + OneHotEncoder:
#  Test score: 0.41768802930159055
#  Params: {'regressor__learning_rate': 0.01, 'regressor__n_estimators': 198}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                 params  mean_train_score  \
# 164  {'regressor__learning_rate': 0.01, 'regressor_...          0.908601
# 162  {'regressor__learning_rate': 0.01, 'regressor_...          0.887072
# 160  {'regressor__learning_rate': 0.01, 'regressor_...          0.855395
#
#      mean_test_score
# 164         0.417688
# 162         0.414729
# 160         0.408093
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# -------------------------------------------
# | Meilleur Model - GradientBoosting |
# -------------------------------------------
# GradientBoosting - StandardScaler + OneHotEncoder:
#  Test score: 0.4105171947618066
#  Params: {'regressor__learning_rate': 0.01, 'regressor__n_estimators': 211}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                 params  mean_train_score  \
# 165  {'regressor__learning_rate': 0.01, 'regressor_...          0.916717
# 163  {'regressor__learning_rate': 0.01, 'regressor_...          0.898313
# 166  {'regressor__learning_rate': 0.01, 'regressor_...          0.924464
#
#      mean_test_score
# 165         0.410517
# 163         0.409680
# 166         0.409223
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# -------------------------------------------
# | Meilleur Model - GradientBoosting |
# -------------------------------------------
# GradientBoosting - MinMaxScaler + OneHotEncoder:
#  Test score: 0.4083439253569378
#  Params: {'regressor__learning_rate': 0.01, 'regressor__n_estimators': 198}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                 params  mean_train_score  \
# 164  {'regressor__learning_rate': 0.01, 'regressor_...          0.908601
# 168  {'regressor__learning_rate': 0.01, 'regressor_...          0.936167
# 172  {'regressor__learning_rate': 0.01, 'regressor_...          0.952015
#
#      mean_test_score
# 164         0.408344
# 168         0.405598
# 172         0.405299
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# -------------------------------------------
# | Meilleur Model - GradientBoosting |
# -------------------------------------------
# GradientBoosting - PolynomialFeatures + OneHotEncoder:
#  Test score: 0.4372009581434992
#  Params: {'regressor__learning_rate': 0.5, 'regressor__n_estimators': 198}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                 params  mean_train_score  \
# 44   {'regressor__learning_rate': 0.5, 'regressor__...          0.999978
# 30   {'regressor__learning_rate': 0.5, 'regressor__...          0.984406
# 163  {'regressor__learning_rate': 0.01, 'regressor_...          0.910268
#
#      mean_test_score
# 44          0.437201
# 30          0.433003
# 163         0.428203
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# -------------------------------------------
# | Meilleur Model - GradientBoosting |
# -------------------------------------------
# GradientBoosting - RobustScaler + TargetEncoder:
#  Test score: 0.5700753974860364
#  Params: {'regressor__learning_rate': 0.25, 'regressor__n_estimators': 292}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                params  mean_train_score  \
# 81  {'regressor__learning_rate': 0.25, 'regressor_...          0.999785
# 85  {'regressor__learning_rate': 0.25, 'regressor_...          0.999867
# 79  {'regressor__learning_rate': 0.25, 'regressor_...          0.999722
#
#     mean_test_score
# 81         0.570075
# 85         0.552506
# 79         0.550220
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# -------------------------------------------
# | Meilleur Model - GradientBoosting |
# -------------------------------------------
# GradientBoosting - StandardScaler + TargetEncoder:
#  Test score: 0.5598027043568298
#  Params: {'regressor__learning_rate': 0.25, 'regressor__n_estimators': 400}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                params  mean_train_score  \
# 89  {'regressor__learning_rate': 0.25, 'regressor_...          0.999913
# 85  {'regressor__learning_rate': 0.25, 'regressor_...          0.999867
# 80  {'regressor__learning_rate': 0.25, 'regressor_...          0.999752
#
#     mean_test_score
# 89         0.559803
# 85         0.552406
# 80         0.549301
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# -------------------------------------------
# | Meilleur Model - GradientBoosting |
# -------------------------------------------
# GradientBoosting - MinMaxScaler + TargetEncoder:
#  Test score: 0.5632435675831514
#  Params: {'regressor__learning_rate': 0.25, 'regressor__n_estimators': 131}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                params  mean_train_score  \
# 69  {'regressor__learning_rate': 0.25, 'regressor_...          0.998813
# 84  {'regressor__learning_rate': 0.25, 'regressor_...          0.999851
# 88  {'regressor__learning_rate': 0.25, 'regressor_...          0.999903
#
#     mean_test_score
# 69         0.563244
# 84         0.558884
# 88         0.558620
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# -------------------------------------------
# | Meilleur Model - GradientBoosting |
# -------------------------------------------
# GradientBoosting - PolynomialFeatures + TargetEncoder:
#  Test score: 0.5710538627224102
#  Params: {'regressor__learning_rate': 0.5, 'regressor__n_estimators': 278}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                params  mean_train_score  \
# 50  {'regressor__learning_rate': 0.5, 'regressor__...          0.999997
# 70  {'regressor__learning_rate': 0.25, 'regressor_...          0.999489
# 79  {'regressor__learning_rate': 0.25, 'regressor_...          0.999897
#
#     mean_test_score
# 50         0.571054
# 70         0.549060
# 79         0.539080
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# ---------------------------------------
# | Meilleur Model - RandomForest |
# ---------------------------------------
# RandomForest - RobustScaler + OneHotEncoder:
#  Test score: 0.5375861685666526
#  Params: {'regressor__min_samples_leaf': 1, 'regressor__n_estimators': 80}
#
# ------------------------
# | Details Models |
# ------------------------
#                                               params  mean_train_score  \
# 7  {'regressor__min_samples_leaf': 1, 'regressor_...          0.924583
# 8  {'regressor__min_samples_leaf': 1, 'regressor_...          0.917958
# 9  {'regressor__min_samples_leaf': 1, 'regressor_...          0.923228
#
#    mean_test_score
# 7         0.537586
# 8         0.536491
# 9         0.525705
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# ---------------------------------------
# | Meilleur Model - RandomForest |
# ---------------------------------------
# RandomForest - StandardScaler + OneHotEncoder:
#  Test score: 0.5170674265118742
#  Params: {'regressor__min_samples_leaf': 1, 'regressor__n_estimators': 170}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                params  mean_train_score  \
# 16  {'regressor__min_samples_leaf': 1, 'regressor_...          0.917063
# 7   {'regressor__min_samples_leaf': 1, 'regressor_...          0.912877
# 0   {'regressor__min_samples_leaf': 1, 'regressor_...          0.920623
#
#     mean_test_score
# 16         0.517067
# 7          0.514555
# 0          0.507829
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# ---------------------------------------
# | Meilleur Model - RandomForest |
# ---------------------------------------
# RandomForest - MinMaxScaler + OneHotEncoder:
#  Test score: 0.5246118341238865
#  Params: {'regressor__min_samples_leaf': 1, 'regressor__n_estimators': 20}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                params  mean_train_score  \
# 1   {'regressor__min_samples_leaf': 1, 'regressor_...          0.909381
# 15  {'regressor__min_samples_leaf': 1, 'regressor_...          0.925147
# 12  {'regressor__min_samples_leaf': 1, 'regressor_...          0.919486
#
#     mean_test_score
# 1          0.524612
# 15         0.506882
# 12         0.499801
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# ---------------------------------------
# | Meilleur Model - RandomForest |
# ---------------------------------------
# RandomForest - PolynomialFeatures + OneHotEncoder:
#  Test score: 0.5366556436502262
#  Params: {'regressor__min_samples_leaf': 1, 'regressor__n_estimators': 70}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                params  mean_train_score  \
# 6   {'regressor__min_samples_leaf': 1, 'regressor_...          0.916065
# 11  {'regressor__min_samples_leaf': 1, 'regressor_...          0.915422
# 19  {'regressor__min_samples_leaf': 1, 'regressor_...          0.918375
#
#     mean_test_score
# 6          0.536656
# 11         0.511103
# 19         0.503096
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# ---------------------------------------
# | Meilleur Model - RandomForest |
# ---------------------------------------
# RandomForest - RobustScaler + TargetEncoder:
#  Test score: 0.5186414855952233
#  Params: {'regressor__min_samples_leaf': 1, 'regressor__n_estimators': 150}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                params  mean_train_score  \
# 14  {'regressor__min_samples_leaf': 1, 'regressor_...          0.929103
# 11  {'regressor__min_samples_leaf': 1, 'regressor_...          0.926128
# 10  {'regressor__min_samples_leaf': 1, 'regressor_...          0.928659
#
#     mean_test_score
# 14         0.518641
# 11         0.509860
# 10         0.497089
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# ---------------------------------------
# | Meilleur Model - RandomForest |
# ---------------------------------------
# RandomForest - StandardScaler + TargetEncoder:
#  Test score: 0.5313224132303934
#  Params: {'regressor__min_samples_leaf': 1, 'regressor__n_estimators': 30}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                params  mean_train_score  \
# 2   {'regressor__min_samples_leaf': 1, 'regressor_...          0.920209
# 9   {'regressor__min_samples_leaf': 1, 'regressor_...          0.931506
# 17  {'regressor__min_samples_leaf': 1, 'regressor_...          0.930659
#
#     mean_test_score
# 2          0.531322
# 9          0.530026
# 17         0.517192
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# ---------------------------------------
# | Meilleur Model - RandomForest |
# ---------------------------------------
# RandomForest - MinMaxScaler + TargetEncoder:
#  Test score: 0.5436869698142484
#  Params: {'regressor__min_samples_leaf': 1, 'regressor__n_estimators': 60}
#
# ------------------------
# | Details Models |
# ------------------------
#                                               params  mean_train_score  \
# 5  {'regressor__min_samples_leaf': 1, 'regressor_...          0.921657
# 6  {'regressor__min_samples_leaf': 1, 'regressor_...          0.922440
# 1  {'regressor__min_samples_leaf': 1, 'regressor_...          0.924724
#
#    mean_test_score
# 5         0.543687
# 6         0.539552
# 1         0.531223
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# ---------------------------------------
# | Meilleur Model - RandomForest |
# ---------------------------------------
# RandomForest - PolynomialFeatures + TargetEncoder:
#  Test score: 0.5314575567021427
#  Params: {'regressor__min_samples_leaf': 1, 'regressor__n_estimators': 50}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                params  mean_train_score  \
# 4   {'regressor__min_samples_leaf': 1, 'regressor_...          0.905909
# 8   {'regressor__min_samples_leaf': 1, 'regressor_...          0.922464
# 10  {'regressor__min_samples_leaf': 1, 'regressor_...          0.925310
#
#     mean_test_score
# 4          0.531458
# 8          0.505231
# 10         0.497195
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------

# %%
best_models_summary_e
# Out:
#                model                                        best_params  \
# 0         ElasticNet  {'regressor__alpha': 1.0000230261160268, 'regr...
# 1         ElasticNet  {'regressor__alpha': 1.0000230261160268, 'regr...
# 2         ElasticNet  {'regressor__alpha': 1.0000230261160268, 'regr...
# 3         ElasticNet  {'regressor__alpha': 4520357245.49924, 'regres...
# 4         ElasticNet  {'regressor__alpha': 1.0000230261160268, 'regr...
# 5         ElasticNet  {'regressor__alpha': 1.0000230261160268, 'regr...
# 6         ElasticNet  {'regressor__alpha': 1.0000230261160268, 'regr...
# 7         ElasticNet  {'regressor__alpha': 4520357245.49924, 'regres...
# 8   GradientBoosting  {'regressor__learning_rate': 0.01, 'regressor_...
# 9   GradientBoosting  {'regressor__learning_rate': 0.01, 'regressor_...
# 10  GradientBoosting  {'regressor__learning_rate': 0.01, 'regressor_...
# 11  GradientBoosting  {'regressor__learning_rate': 0.5, 'regressor__...
# 12  GradientBoosting  {'regressor__learning_rate': 0.25, 'regressor_...
# 13  GradientBoosting  {'regressor__learning_rate': 0.25, 'regressor_...
# 14  GradientBoosting  {'regressor__learning_rate': 0.25, 'regressor_...
# 15  GradientBoosting  {'regressor__learning_rate': 0.5, 'regressor__...
# 16      RandomForest  {'regressor__min_samples_leaf': 1, 'regressor_...
# 17      RandomForest  {'regressor__min_samples_leaf': 1, 'regressor_...
# 18      RandomForest  {'regressor__min_samples_leaf': 1, 'regressor_...
# 19      RandomForest  {'regressor__min_samples_leaf': 1, 'regressor_...
# 20      RandomForest  {'regressor__min_samples_leaf': 1, 'regressor_...
# 21      RandomForest  {'regressor__min_samples_leaf': 1, 'regressor_...
# 22      RandomForest  {'regressor__min_samples_leaf': 1, 'regressor_...
# 23      RandomForest  {'regressor__min_samples_leaf': 1, 'regressor_...
#
#     Test_score    fit_time
# 0        0.476   20.317819
# 1        0.507    8.649152
# 2        0.210    8.835830
# 3        0.578   36.675705
# 4        0.355   31.019262
# 5        0.380   29.264947
# 6        0.004   28.345825
# 7        0.463   38.992189
# 8        0.418  102.705728
# 9        0.411  108.982494
# 10       0.408  121.630300
# 11       0.437  289.383310
# 12       0.570  126.330607
# 13       0.560  112.023657
# 14       0.563  102.508472
# 15       0.571  230.917613
# 16       0.538   53.889065
# 17       0.517   58.909010
# 18       0.525   62.749767
# 19       0.537   75.750382
# 20       0.519   34.593803
# 21       0.531   33.926562
# 22       0.544   33.245229
# 23       0.531   65.034215

# %%
selected_models = []

for result_key, result_info in models_wth_energy_star.items():
    test_score = result_info["Test score"]
    
    if test_score > 0.55:
        selected_models.append((result_key, result_info["Params"], test_score))

print_titre("Les modèles ayant un score de cross validation supérieur à 0.65 sont :")

for model, config, test_score in selected_models:
    print(f"Nom du modèle : {model}\nConfiguration : {config}\nTest Score : {test_score}")
# Out:
# --------------------------------------------------------------------------------
# | Les modèles ayant un score de cross validation supérieur à 0.65 sont : |
# --------------------------------------------------------------------------------
# Nom du modèle : ElasticNet - PolynomialFeatures + OneHotEncoder
# Configuration : {'regressor__alpha': 4520357245.49924, 'regressor__l1_ratio': 0.5}
# Test Score : 0.5784302673567744
# Nom du modèle : GradientBoosting - RobustScaler + TargetEncoder
# Configuration : {'regressor__learning_rate': 0.25, 'regressor__n_estimators': 292}
# Test Score : 0.5700753974860364
# Nom du modèle : GradientBoosting - StandardScaler + TargetEncoder
# Configuration : {'regressor__learning_rate': 0.25, 'regressor__n_estimators': 400}
# Test Score : 0.5598027043568298
# Nom du modèle : GradientBoosting - MinMaxScaler + TargetEncoder
# Configuration : {'regressor__learning_rate': 0.25, 'regressor__n_estimators': 131}
# Test Score : 0.5632435675831514
# Nom du modèle : GradientBoosting - PolynomialFeatures + TargetEncoder
# Configuration : {'regressor__learning_rate': 0.5, 'regressor__n_estimators': 278}
# Test Score : 0.5710538627224102

# %%
kkk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5672\4032765053.py in <module>
# ----> 1 kkk
#
# NameError: name 'kkk' is not defined

# %%
num_preprocessor = PolynomialFeatures()
cat_preprocessor = TargetEncoder(cols=categorical_features)

# Transformer
preprocessor = ColumnTransformer(
    transformers=[
        ("num", num_preprocessor, numeric_features),
        ("cat", cat_preprocessor, categorical_features),
    ]
)

# %%
# Diviser les données
X = energy_benchmarking_ml.dropna().drop(columns=['SiteEnergyUseWN(kBtu)'])
y = energy_benchmarking_ml.dropna()['SiteEnergyUseWN(kBtu)']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

best_model = GradientBoostingRegressor(learning_rate=0.5, n_estimators=278)

pipeline = Pipeline(
    steps=[("preprocessor", preprocessor), ("regressor", best_model)]
)

pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', PolynomialFeatures(),
#                                                   ['Ancienneté',
#                                                    'BuildingAreaPercentage',
#                                                    'ParkingAreaPercentage',
#                                                    'NumberofBuildings',
#                                                    'NumberofFloors',
#                                                    'PropertyGFATotal',
#                                                    'ENERGYSTARScore']),
#                                                  ('cat',
#                                                   TargetEncoder(cols=['Neighborhood',
#                                                                       'PrimaryPropertyType',
#                                                                       'BuildingType',
#                                                                       'LargestPropertyUseType']),
#                                                   ['Neighborhood',
#                                                    'PrimaryPropertyType',
#                                                    'BuildingType',
#                                                    'LargestPropertyUseType'])])),
#                 ('regressor',
#                  GradientBoostingRegressor(learning_rate=0.5,
#                                            n_estimators=278))])

# %%
# Entraîner la pipeline sur l'ensemble d'entraînement
pipeline.fit(X_train, y_train)

# Prédire avec le modèle sur l'ensemble de test
y_pred = pipeline.predict(X_test)

# %%
print("R² (Test Set) :", round(r2_score(y_test, y_pred),2))
# Out:
# R² (Test Set) : 0.86

# %% [markdown]
# # Model GradientBoostingRegressor

# %%
# GridSearchCV pour GradientBoostingRegressor
grid_gb = {
    'regressor__learning_rate': [1, 0.5, 0.25, 0.1, 0.05, 0.01],
    'regressor__n_estimators': np.linspace(10, 400, 30, dtype=int)
}


cv_gb = train_model(pipeline, grid_gb, X_train, y_train)
# Out:
# Fitting 5 folds for each of 180 candidates, totalling 900 fits

# %% [markdown]
# # Analyse de l'importance des variables

# %%
# !pip install shap
import shap
shap.initjs()
# Out:
# Requirement already satisfied: shap in c:\users\farid\anaconda3\lib\site-packages (0.44.0)
# Requirement already satisfied: scipy in c:\users\farid\anaconda3\lib\site-packages (from shap) (1.9.1)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\farid\anaconda3\lib\site-packages (from shap) (4.64.1)
# Requirement already satisfied: slicer==0.0.7 in c:\users\farid\anaconda3\lib\site-packages (from shap) (0.0.7)
# Requirement already satisfied: packaging>20.9 in c:\users\farid\anaconda3\lib\site-packages (from shap) (21.3)
# Requirement already satisfied: cloudpickle in c:\users\farid\anaconda3\lib\site-packages (from shap) (2.0.0)
# Requirement already satisfied: numba in c:\users\farid\anaconda3\lib\site-packages (from shap) (0.55.1)
# Requirement already satisfied: numpy in c:\users\farid\anaconda3\lib\site-packages (from shap) (1.21.5)
# Requirement already satisfied: pandas in c:\users\farid\anaconda3\lib\site-packages (from shap) (1.4.4)
# Requirement already satisfied: scikit-learn in c:\users\farid\anaconda3\lib\site-packages (from shap) (1.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\farid\anaconda3\lib\site-packages (from packaging>20.9->shap) (3.0.9)
# Requirement already satisfied: colorama in c:\users\farid\anaconda3\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.5)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\farid\anaconda3\lib\site-packages (from numba->shap) (0.38.0)
# Requirement already satisfied: setuptools in c:\users\farid\anaconda3\lib\site-packages (from numba->shap) (63.4.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\farid\anaconda3\lib\site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\farid\anaconda3\lib\site-packages (from pandas->shap) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\farid\anaconda3\lib\site-packages (from scikit-learn->shap) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\farid\anaconda3\lib\site-packages (from scikit-learn->shap) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\farid\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %% [markdown]
# La valeur de Shapley, dans le context de l'interpretation de modèles d'apprentissage automatique, permet d'évaluer l'inpact de chaque caractérisqtique sur une prédiction donnée.
# **Elle fait cela en calculant la contibution moyenne de chaque caractéristique à la prédiction sur toutes les combinaisons possible de caractéristiques.**

# %% [markdown]
# # Standard SHAP values

# %%
best_model = cv_gb.best_estimator_

# %%
final_model = cv_gb.best_estimator_.named_steps['regressor']

# %%
# Créer un explainer pour le modèle final avec les noms de fonctionnalités
feature_names = best_model.named_steps['preprocessor'].get_feature_names_out()
explainer = shap.Explainer(final_model, feature_names=feature_names)

# %%
X_test_preprocessed = cv_gb.best_estimator_.named_steps['preprocessor'].transform(X_test)

# %%
shap_values = explainer.shap_values(X_test_preprocessed)

# %%
plt.figure(figsize=(10, 6), dpi=60)
shap.summary_plot(shap_values, X_test_preprocessed, feature_names=feature_names, plot_type="bar")

# %%
# Représentation de l'effet des variables sur un bâtiment
shap.initjs()
i = 90
shap_values_i = explainer.shap_values(X_test_preprocessed[i].reshape(1, -1))
shap.force_plot(explainer.expected_value, shap_values_i, X_test_preprocessed[i], show=True, matplotlib=True, text_rotation=15, feature_names=feature_names)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %% [markdown]
# # Analyse Comparative sans la variable `ENERGYSTARScore `

# %%
numeric_features = ['Ancienneté', 'BuildingAreaPercentage', 'ParkingAreaPercentage',
                     'NumberofBuildings', 'NumberofFloors', 'PropertyGFATotal']

categorical_features = ['Neighborhood', 'PrimaryPropertyType', 'BuildingType', 'LargestPropertyUseType']

# %%
energy_benchmarking_ml = energy_benchmarking_ml[numeric_features + categorical_features + ['SiteEnergyUseWN(kBtu)']]

# %%
energy_benchmarking_ml.columns
# Out:
# Index(['Ancienneté', 'BuildingAreaPercentage', 'ParkingAreaPercentage',
#        'NumberofBuildings', 'NumberofFloors', 'PropertyGFATotal',
#        'Neighborhood', 'PrimaryPropertyType', 'BuildingType',
#        'LargestPropertyUseType', 'SiteEnergyUseWN(kBtu)'],
#       dtype='object')

# %%
# Sélectionner 1073 aléatoirement
# energy_benchmarking_ml_subset = energy_benchmarking_ml.iloc[:1073]
energy_benchmarking_ml_subset = energy_benchmarking_ml.sample(n=1073)

# %%
energy_benchmarking_ml_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1073 entries, 213 to 952
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Ancienneté              1073 non-null   int64
#  1   BuildingAreaPercentage  1073 non-null   float64
#  2   ParkingAreaPercentage   1073 non-null   float64
#  3   NumberofBuildings       1073 non-null   float64
#  4   NumberofFloors          1073 non-null   int64
#  5   PropertyGFATotal        1073 non-null   int64
#  6   Neighborhood            1073 non-null   object
#  7   PrimaryPropertyType     1073 non-null   object
#  8   BuildingType            1073 non-null   object
#  9   LargestPropertyUseType  1073 non-null   object
#  10  SiteEnergyUseWN(kBtu)   1073 non-null   float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 100.6+ KB

# %%
# Diviser les données
X = energy_benchmarking_ml_subset.dropna().drop(columns=['SiteEnergyUseWN(kBtu)'])
y = energy_benchmarking_ml_subset.dropna()['SiteEnergyUseWN(kBtu)']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=70)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1073 entries, 213 to 952
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Ancienneté              1073 non-null   int64
#  1   BuildingAreaPercentage  1073 non-null   float64
#  2   ParkingAreaPercentage   1073 non-null   float64
#  3   NumberofBuildings       1073 non-null   float64
#  4   NumberofFloors          1073 non-null   int64
#  5   PropertyGFATotal        1073 non-null   int64
#  6   Neighborhood            1073 non-null   object
#  7   PrimaryPropertyType     1073 non-null   object
#  8   BuildingType            1073 non-null   object
#  9   LargestPropertyUseType  1073 non-null   object
# dtypes: float64(3), int64(3), object(4)
# memory usage: 92.2+ KB

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 1073 entries, 213 to 952
# Series name: SiteEnergyUseWN(kBtu)
# Non-Null Count  Dtype
# --------------  -----
# 1073 non-null   float64
# dtypes: float64(1)
# memory usage: 16.8 KB

# %%
# Liste des modèles à tester
models = {
   # "KNN": KNeighborsRegressor(),
   # "ElasticNet": ElasticNet(),
    "GradientBoosting": GradientBoostingRegressor(),
   # "SVR": SVR(),
    "RandomForest": RandomForestRegressor()
}

preprocessor_configs = [
    ("RobustScaler + OneHotEncoder", RobustScaler(), OneHotEncoder(handle_unknown='ignore')),
    ("StandardScaler + OneHotEncoder", StandardScaler(), OneHotEncoder(handle_unknown='ignore')),
    ("MinMaxScaler + OneHotEncoder", MinMaxScaler(), OneHotEncoder(handle_unknown='ignore')),
    # ("PolynomialFeatures + OneHotEncoder", PolynomialFeatures(), OneHotEncoder(handle_unknown='ignore')),
    ("RobustScaler + TargetEncoder", RobustScaler(), TargetEncoder(cols=categorical_features)),
    ("StandardScaler + TargetEncoder", StandardScaler(), TargetEncoder(cols=categorical_features)),
    ("MinMaxScaler + TargetEncoder", MinMaxScaler(), TargetEncoder(cols=categorical_features)),
    # ("PolynomialFeatures + TargetEncoder", PolynomialFeatures(), TargetEncoder(cols=categorical_features)),
]

# %%
models_no_energy_star, best_models_summary_no_e = run_models_with_preprocessors(models, preprocessor_configs, grid_configs, X_train, y_train, X_test, y_test, numeric_features, categorical_features)
# Out:
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# -------------------------------------------
# | Meilleur Model - GradientBoosting |
# -------------------------------------------
# GradientBoosting - RobustScaler + OneHotEncoder:
#  Test score: 0.34393612460163536
#  Params: {'regressor__learning_rate': 0.1, 'regressor__n_estimators': 90}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                params  mean_train_score  \
# 96  {'regressor__learning_rate': 0.1, 'regressor__...          0.963649
# 58  {'regressor__learning_rate': 0.5, 'regressor__...          0.999948
# 46  {'regressor__learning_rate': 0.5, 'regressor__...          0.999596
#
#     mean_test_score
# 96         0.343936
# 58         0.338359
# 46         0.336471
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# -------------------------------------------
# | Meilleur Model - GradientBoosting |
# -------------------------------------------
# GradientBoosting - StandardScaler + OneHotEncoder:
#  Test score: 0.37860835491588113
#  Params: {'regressor__learning_rate': 0.5, 'regressor__n_estimators': 23}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                params  mean_train_score  \
# 31  {'regressor__learning_rate': 0.5, 'regressor__...          0.974723
# 36  {'regressor__learning_rate': 0.5, 'regressor__...          0.996415
# 30  {'regressor__learning_rate': 0.5, 'regressor__...          0.947465
#
#     mean_test_score
# 31         0.378608
# 36         0.355163
# 30         0.352822
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# -------------------------------------------
# | Meilleur Model - GradientBoosting |
# -------------------------------------------
# GradientBoosting - MinMaxScaler + OneHotEncoder:
#  Test score: 0.37145224806966964
#  Params: {'regressor__learning_rate': 0.5, 'regressor__n_estimators': 23}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                params  mean_train_score  \
# 31  {'regressor__learning_rate': 0.5, 'regressor__...          0.974723
# 30  {'regressor__learning_rate': 0.5, 'regressor__...          0.947465
# 32  {'regressor__learning_rate': 0.5, 'regressor__...          0.984366
#
#     mean_test_score
# 31         0.371452
# 30         0.363135
# 32         0.360542
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# -------------------------------------------
# | Meilleur Model - GradientBoosting |
# -------------------------------------------
# GradientBoosting - RobustScaler + TargetEncoder:
#  Test score: 0.39572038090443423
#  Params: {'regressor__learning_rate': 0.25, 'regressor__n_estimators': 23}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                 params  mean_train_score  \
# 61   {'regressor__learning_rate': 0.25, 'regressor_...          0.950510
# 64   {'regressor__learning_rate': 0.25, 'regressor_...          0.982507
# 134  {'regressor__learning_rate': 0.05, 'regressor_...          0.967336
#
#      mean_test_score
# 61          0.395720
# 64          0.346929
# 134         0.337972
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# -------------------------------------------
# | Meilleur Model - GradientBoosting |
# -------------------------------------------
# GradientBoosting - StandardScaler + TargetEncoder:
#  Test score: 0.38851046712142256
#  Params: {'regressor__learning_rate': 0.1, 'regressor__n_estimators': 77}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                 params  mean_train_score  \
# 95   {'regressor__learning_rate': 0.1, 'regressor__...          0.960025
# 64   {'regressor__learning_rate': 0.25, 'regressor_...          0.982507
# 107  {'regressor__learning_rate': 0.1, 'regressor__...          0.988839
#
#      mean_test_score
# 95          0.388510
# 64          0.356694
# 107         0.336624
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# -------------------------------------------
# | Meilleur Model - GradientBoosting |
# -------------------------------------------
# GradientBoosting - MinMaxScaler + TargetEncoder:
#  Test score: 0.35793731310413684
#  Params: {'regressor__learning_rate': 0.1, 'regressor__n_estimators': 117}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                 params  mean_train_score  \
# 98   {'regressor__learning_rate': 0.1, 'regressor__...          0.974268
# 66   {'regressor__learning_rate': 0.25, 'regressor_...          0.988883
# 128  {'regressor__learning_rate': 0.05, 'regressor_...          0.950364
#
#      mean_test_score
# 98          0.357937
# 66          0.350017
# 128         0.329830
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# ---------------------------------------
# | Meilleur Model - RandomForest |
# ---------------------------------------
# RandomForest - RobustScaler + OneHotEncoder:
#  Test score: 0.38833690892206363
#  Params: {'regressor__min_samples_leaf': 4, 'regressor__n_estimators': 10}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                params  mean_train_score  \
# 20  {'regressor__min_samples_leaf': 4, 'regressor_...          0.648745
# 7   {'regressor__min_samples_leaf': 1, 'regressor_...          0.930299
# 28  {'regressor__min_samples_leaf': 4, 'regressor_...          0.669836
#
#     mean_test_score
# 20         0.388337
# 7          0.376750
# 28         0.375115
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# ---------------------------------------
# | Meilleur Model - RandomForest |
# ---------------------------------------
# RandomForest - StandardScaler + OneHotEncoder:
#  Test score: 0.395562088305888
#  Params: {'regressor__min_samples_leaf': 1, 'regressor__n_estimators': 10}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                params  mean_train_score  \
# 0   {'regressor__min_samples_leaf': 1, 'regressor_...          0.912350
# 23  {'regressor__min_samples_leaf': 4, 'regressor_...          0.662881
# 24  {'regressor__min_samples_leaf': 4, 'regressor_...          0.668681
#
#     mean_test_score
# 0          0.395562
# 23         0.384553
# 24         0.366090
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# ---------------------------------------
# | Meilleur Model - RandomForest |
# ---------------------------------------
# RandomForest - MinMaxScaler + OneHotEncoder:
#  Test score: 0.3961319417283639
#  Params: {'regressor__min_samples_leaf': 4, 'regressor__n_estimators': 70}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                params  mean_train_score  \
# 26  {'regressor__min_samples_leaf': 4, 'regressor_...          0.664637
# 27  {'regressor__min_samples_leaf': 4, 'regressor_...          0.660356
# 28  {'regressor__min_samples_leaf': 4, 'regressor_...          0.665483
#
#     mean_test_score
# 26         0.396132
# 27         0.392432
# 28         0.391356
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# ---------------------------------------
# | Meilleur Model - RandomForest |
# ---------------------------------------
# RandomForest - RobustScaler + TargetEncoder:
#  Test score: 0.52030732722686
#  Params: {'regressor__min_samples_leaf': 4, 'regressor__n_estimators': 90}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                params  mean_train_score  \
# 28  {'regressor__min_samples_leaf': 4, 'regressor_...          0.713003
# 32  {'regressor__min_samples_leaf': 4, 'regressor_...          0.720479
# 37  {'regressor__min_samples_leaf': 4, 'regressor_...          0.724938
#
#     mean_test_score
# 28         0.520307
# 32         0.517187
# 37         0.512340
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# ---------------------------------------
# | Meilleur Model - RandomForest |
# ---------------------------------------
# RandomForest - StandardScaler + TargetEncoder:
#  Test score: 0.5111554759042801
#  Params: {'regressor__min_samples_leaf': 4, 'regressor__n_estimators': 150}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                params  mean_train_score  \
# 34  {'regressor__min_samples_leaf': 4, 'regressor_...          0.713580
# 29  {'regressor__min_samples_leaf': 4, 'regressor_...          0.719913
# 25  {'regressor__min_samples_leaf': 4, 'regressor_...          0.713017
#
#     mean_test_score
# 34         0.511155
# 29         0.508363
# 25         0.504812
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# ---------------------------------------
# | Meilleur Model - RandomForest |
# ---------------------------------------
# RandomForest - MinMaxScaler + TargetEncoder:
#  Test score: 0.514323178588326
#  Params: {'regressor__min_samples_leaf': 4, 'regressor__n_estimators': 120}
#
# ------------------------
# | Details Models |
# ------------------------
#                                                params  mean_train_score  \
# 31  {'regressor__min_samples_leaf': 4, 'regressor_...          0.718266
# 28  {'regressor__min_samples_leaf': 4, 'regressor_...          0.719510
# 25  {'regressor__min_samples_leaf': 4, 'regressor_...          0.720594
#
#     mean_test_score
# 31         0.514323
# 28         0.512528
# 25         0.512405
# -------------------------------------------------------
# | Scores Moyens d'Entraînement et de Validation |
# -------------------------------------------------------

# %%
kkk

# %%
best_models_summary_no_e
# Out:
#                model                                        best_params  \
# 0   GradientBoosting  {'regressor__learning_rate': 0.1, 'regressor__...
# 1   GradientBoosting  {'regressor__learning_rate': 0.5, 'regressor__...
# 2   GradientBoosting  {'regressor__learning_rate': 0.5, 'regressor__...
# 3   GradientBoosting  {'regressor__learning_rate': 0.25, 'regressor_...
# 4   GradientBoosting  {'regressor__learning_rate': 0.1, 'regressor__...
# 5   GradientBoosting  {'regressor__learning_rate': 0.1, 'regressor__...
# 6       RandomForest  {'regressor__min_samples_leaf': 4, 'regressor_...
# 7       RandomForest  {'regressor__min_samples_leaf': 1, 'regressor_...
# 8       RandomForest  {'regressor__min_samples_leaf': 4, 'regressor_...
# 9       RandomForest  {'regressor__min_samples_leaf': 4, 'regressor_...
# 10      RandomForest  {'regressor__min_samples_leaf': 4, 'regressor_...
# 11      RandomForest  {'regressor__min_samples_leaf': 4, 'regressor_...
#
#     Test_score   fit_time
# 0        0.344  88.463725
# 1        0.379  74.501848
# 2        0.371  73.335440
# 3        0.396  92.111575
# 4        0.389  95.599899
# 5        0.358  95.354249
# 6        0.388  56.948990
# 7        0.396  56.619560
# 8        0.396  53.089218
# 9        0.520  32.547445
# 10       0.511  32.193234
# 11       0.514  31.904969

# %%
selected_models = []

for result_key, result_info in models_no_energy_star.items():
    test_score = result_info["Test score"]
    
    if test_score > 0.50:
        selected_models.append((result_key, result_info["Params"], test_score))

print_titre("Les modèles ayant un score de test supérieur à 0.50 sont :")

for model, config, test_score in selected_models:
    print(f"Nom du modèle : {model}\nConfiguration : {config}\nTest Score : {test_score}")
# Out:
# --------------------------------------------------------------------
# | Les modèles ayant un score de test supérieur à 0.50 sont : |
# --------------------------------------------------------------------
# Nom du modèle : RandomForest - RobustScaler + TargetEncoder
# Configuration : {'regressor__min_samples_leaf': 4, 'regressor__n_estimators': 90}
# Test Score : 0.52030732722686
# Nom du modèle : RandomForest - StandardScaler + TargetEncoder
# Configuration : {'regressor__min_samples_leaf': 4, 'regressor__n_estimators': 150}
# Test Score : 0.5111554759042801
# Nom du modèle : RandomForest - MinMaxScaler + TargetEncoder
# Configuration : {'regressor__min_samples_leaf': 4, 'regressor__n_estimators': 120}
# Test Score : 0.514323178588326

# %%
num_preprocessor = PolynomialFeatures()
cat_preprocessor = TargetEncoder(cols=categorical_features)

# Transformer
preprocessor = ColumnTransformer(
    transformers=[
        ("num", num_preprocessor, numeric_features),
        ("cat", cat_preprocessor, categorical_features),
    ]
)

# %%
# Diviser les données
X = energy_benchmarking_ml.dropna().drop(columns=['SiteEnergyUseWN(kBtu)'])
y = energy_benchmarking_ml.dropna()['SiteEnergyUseWN(kBtu)']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=70)

best_model_no_energy = RandomForestRegressor(min_samples_leaf=4, n_estimators=90)

pipeline_no_e = Pipeline(
    steps=[("preprocessor", preprocessor), ("regressor", best_model_no_energy)]
)

pipeline_no_e
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', PolynomialFeatures(),
#                                                   ['Ancienneté',
#                                                    'BuildingAreaPercentage',
#                                                    'ParkingAreaPercentage',
#                                                    'NumberofBuildings',
#                                                    'NumberofFloors',
#                                                    'PropertyGFATotal']),
#                                                  ('cat',
#                                                   TargetEncoder(cols=['Neighborhood',
#                                                                       'PrimaryPropertyType',
#                                                                       'BuildingType',
#                                                                       'LargestPropertyUseType']),
#                                                   ['Neighborhood',
#                                                    'PrimaryPropertyType',
#                                                    'BuildingType',
#                                                    'LargestPropertyUseType'])])),
#                 ('regressor',
#                  RandomForestRegressor(min_samples_leaf=4, n_estimators=90))])

# %%
# Entraîner la pipeline sur l'ensemble d'entraînement
pipeline_no_e.fit(X_train, y_train)

# Prédire avec le modèle sur l'ensemble de test
y_pred_no_e = pipeline_no_e.predict(X_test)

# %%
print("R² (Test Set) :", round(r2_score(y_test, y_pred_no_e),2))
# Out:
# R² (Test Set) : 0.2
